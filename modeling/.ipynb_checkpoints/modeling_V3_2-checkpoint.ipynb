# %% [markdown]
# ## version3:  モデリング時のスコアシートの形式を変換したもの（モデル選定をランダムフォレストに変えるため）

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from matplotlib import pyplot as plt
import seaborn
from pandas import DataFrame
from tqdm import tqdm
from imblearn.under_sampling import RandomUnderSampler #アンダーサンプリング用
from sklearn.model_selection import train_test_split
import pickle
# 機械学習用
from sklearn.cluster import KMeans #クラスタリング用
from sklearn.ensemble import RandomForestClassifier#ランダムフォレスト
from copy import deepcopy as cp
from sklearn.linear_model import LogisticRegression
import time
import datetime
import os #ディレクトリ作成用
import xgboost as xgb
import sys
#自作のモジュールのインポート
sys.path.append("..")
import module.master as master
import module.modeling_scores as modeling

# %% [markdown]
# # モデルのスコア保存のため箱作り

# %%
place_master=master.get_place_master()
for place in place_master.items():
    #print(place[0],place[1],'\n')
    place_name=place[1]
    dir_path = "../../bot_database/{place_name}/model_score_{place_name}/".format(place_name=place_name)#作成したデータの書き込み先#使用するデータの読み込み
    if os.path.exists(dir_path)==False:
        os.makedirs(dir_path)
    else:
        pass

# %% [markdown]
# # 3年分でモデル選定のためのモデル作成のためのパラメータ探索

# %%
#データ格納用のディレクトリ作り
version='V3_2'#バージョン
years=[2018,2019,2020]#使用する三年分のデータ（古い順で！！！）

place_master=master.get_place_master()
for place in place_master.items():
    place_name=place[1]
    
    ################################################========================================================================================================================
    ################################################========================================================================================================================
    ################################################========================================================================================================================
    ################################################========================================================================================================================
    #各会場の学習データの読み込みと加工
    result_filepath="../..//bot_database/{place_name}/{place_name}_train/train_{place_name}.csv".format(place_name=place_name)#作成したデータの書き込み先#使用するデータの読み込み
    result_base_df=pd.read_csv(result_filepath)
    result_base_df=result_base_df.drop(["Unnamed: 0"],axis=1)
    modeling.version_3_2_3years(version,years,place_name,result_base_df)
# Out:
#   0%|                                                                                           | 0/28 [00:00<?, ?it/s]
# kiryu
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
#   4%|██▊                                                                             | 1/28 [07:44<3:29:08, 464.75s/it]..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
#   7%|█████▋                                                                          | 2/28 [15:18<3:18:27, 458.00s/it]..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
#  18%|██████████████▎                                                                 | 5/28 [37:44<2:52:51, 450.91s/it]..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# 100%|███████████████████████████████████████████████████████████████████████████████| 28/28 [3:25:01<00:00, 439.34s/it]
#   0%|                                                                                           | 0/28 [00:00<?, ?it/s]
# toda
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
#   7%|█████▋                                                                          | 2/28 [15:06<3:16:16, 452.96s/it]..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
#  14%|███████████▍                                                                    | 4/28 [29:53<2:58:23, 445.97s/it]..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ...
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:926: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:930: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
#  43%|█████████████████████████████████                                            | 12/28 [1:31:30<1:58:39, 444.95s/it]..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# ..\module\modeling_scores.py:932: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(year_df["gain"].sum()/(100*year_df["pred"].sum()))*100
# 100%|███████████████████████████████████████████████████████████████████████████████| 28/28 [3:27:09<00:00, 443.93s/it]

# %% [markdown]
# # 3年分でモデル選定のためのモデル作成のためのパラメータ探索

# %%
#データ格納用のディレクトリ作り
version='V3_2'#バージョン
years=[2019,2020]#使用する三年分のデータ（古い順で！！！）

place_master=master.get_place_master()
for place in place_master.items():
    place_name=place[1]
    
    ################################################========================================================================================================================
    ################################################========================================================================================================================
    ################################################========================================================================================================================
    ################################################========================================================================================================================
    #各会場の学習データの読み込みと加工
    result_filepath="../..//bot_database/{place_name}/{place_name}_train/train_{place_name}.csv".format(place_name=place_name)#作成したデータの書き込み先#使用するデータの読み込み
    result_base_df=pd.read_csv(result_filepath)
    result_base_df=result_base_df.drop(["Unnamed: 0"],axis=1)
    modeling.version_3_2(version,years,place_name,result_base_df)
# Out:
#   0%|                                                                                           | 0/28 [00:00<?, ?it/s]
# kiryu
# 100%|███████████████████████████████████████████████████████████████████████████████| 28/28 [3:04:55<00:00, 396.27s/it]
#   0%|                                                                                           | 0/28 [00:00<?, ?it/s]
# toda
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
#   4%|██▊                                                                             | 1/28 [07:00<3:09:10, 420.40s/it]..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
#  11%|████████▌                                                                       | 3/28 [20:33<2:50:38, 409.55s/it]..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
#  29%|██████████████████████▊                                                         | 8/28 [54:09<2:14:14, 402.74s/it]..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
#  36%|███████████████████████████▌                                                 | 10/28 [1:07:31<2:00:28, 401.57s/it]..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
#  75%|███████████████████████████████████████████████████████████▎                   | 21/28 [2:18:40<45:18, 388.40s/it]..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# 100%|███████████████████████████████████████████████████████████████████████████████| 28/28 [3:03:50<00:00, 393.96s/it]
#   0%|                                                                                           | 0/28 [00:00<?, ?it/s]
# edogawa
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
#   7%|█████▋                                                                          | 2/28 [13:44<2:58:00, 410.78s/it]..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
# ...
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
#  29%|██████████████████████▊                                                         | 8/28 [57:20<2:19:13, 417.67s/it]..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
#  36%|███████████████████████████▌                                                 | 10/28 [1:11:13<2:05:01, 416.77s/it]..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1113: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['gain_year{year}'.format(year=label)]=(model_score_s['total_get_year{year}'.format(year=label)]/model_score_s['total_use_year{year}'.format(year=label)])*100
# ..\module\modeling_scores.py:1117: RuntimeWarning: invalid value encountered in double_scalars
#   model_score_s['buy_hit_per_year{year}'.format(year=label)]=(model_score_s['num_hit_year{year}'.format(year=label)]/ model_score_s['num_pred_year{year}'.format(year=label)])*100
# 100%|███████████████████████████████████████████████████████████████████████████████| 28/28 [3:08:17<00:00, 403.49s/it]
